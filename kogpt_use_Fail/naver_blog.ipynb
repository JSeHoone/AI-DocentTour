# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "JmnMMdzgCYser7RBx1Gw"
client_secret = "nKQLDSxVE1"
encText = urllib.parse.quote("예산")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100&start=1&sort=date" # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 07 Jun 2023 22:11:02 +0900",
# 	"total":4532995,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"남양주 폐차장 기사를 보내드려 차량을 입고시킵니다",
# 			"link":"https:\/\/blog.naver.com\/seeon-bs\/223122891075",
# 			"description":"2023년 남양주 조기폐차는 1,575대를 조기폐차할 <b>예산<\/b>을 확보하여 신청 접수 받았습니다. <b>예산<\/b> 범위 내에서 선착순 접수였으며 <b>예산<\/b>이 소진되어 6월 5일 마감하였습니다. 2023년 하반기에는 추가로 <b>예산<\/b>이... ",
# 			"bloggername":"하하호호",
# 			"bloggerlink":"blog.naver.com\/seeon-bs",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"1톤크레인중고 동해433 4륜 2천킬로 신차",
# 			"link":"https:\/\/blog.naver.com\/5012army\/223122890492",
# 			"description":"신차급 1톤크레인중고 동해433 마음에는 무조건 들수밖에 없는데 <b>예산<\/b>이 부족한 경우가 있겠죠. 고가의 장비차량을 현금으로 주고 사는 사업장은 사실상 잘 없죠 그렇기에 분할납부를 알아봐야 하는데... ",
# 			"bloggername":"조금전",
# 			"bloggerlink":"blog.naver.com\/5012army",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"결혼 예물 고민하다가 마침내 최종 선택!",
# 			"link":"https:\/\/blog.naver.com\/rldqo5\/223122889985",
# ...

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

data = json.loads(response_body)
print(f"예산에 대한 네이버 블로그 검색 총 수 : {data['total']}")
# Out:
# 예산에 대한 네이버 블로그 검색 총 수 : 4532995

# %%
## 예산군에 대한 정보가 아닌 "예산" (금액)에 대한 이야기가 더 많은 것 같음
df = pd.DataFrame(data['items'])
# data['items']
df[df['title'].str.contains('예산')]
# Out:
#                                           title  \
# 22                        <b>예산</b>폐차 조기폐차 같이하자
# 25             <b>예산</b> 취팔로마 cctv 3대설치 완료했습니다.
# 47           부산화환 근조화환업체 <b>예산</b>장례식장 저렴하고 빠르고
# 48                                <b>예산</b> 수덕사
# 65                            <b>예산</b> 대흥 슬로시티
# 68  배스낚시 : 낚시여행 2일차 <b>예산</b> 예당저수지 배스낚시 정보...
# 83                               <b>예산</b> 신리성지
#
#                                               link  \
# 22    https://blog.naver.com/wkdtpquf/223122883250
# 25      https://blog.naver.com/celand/223122881322
# 47   https://blog.naver.com/catchtvt3/223122872347
# 48    https://blog.naver.com/shine7hk/223122871858
# 65    https://blog.naver.com/lalalong/223122866139
# 68       https://blog.naver.com/13pjy/223122865819
# 83  https://blog.naver.com/yhyang_hae/223122862587
#
#                                           description  \
# 22  이분은 <b>예산</b>폐차 의뢰후 저희 회사에서 SUV스포티지을 구매후 조기폐차 ...
# ...

# %%
df.to_csv('예산_블로그_검색.csv', index=False)

# %% [markdown]
# ----

# %%
## 예산 역사로 블로그 검색 변경 
import os
import sys
import urllib.request
client_id = "JmnMMdzgCYser7RBx1Gw"
client_secret = "nKQLDSxVE1"
encText = urllib.parse.quote("예산 역사")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100&start=1&sort=date" # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 07 Jun 2023 22:21:21 +0900",
# 	"total":297689,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"두촌면 인근(隣近)에 춘원도청(春原道廳) 춘원도의회 신설 홍천... ",
# 			"link":"https:\/\/blog.naver.com\/msk7613\/223122889302",
# 			"description":"1.구,시,군,동,읍,면,리의 명칭,주소 등은 읍지(邑誌),실록 등에 근거한 <b>역사<\/b>문화지명 사용을 원칙으로 하며 명칭 제·개정은 국무령이 <b>역사<\/b>문화재 전문가 등과 협의하여 정할 수 있다. ④대한국은 정치·경제... ",
# 			"bloggername":"김민수의 대한국 황실 조선국 왕실 역사 고궁 박물관",
# 			"bloggerlink":"blog.naver.com\/msk7613",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"관사(a \/ the)",
# 			"link":"https:\/\/blog.naver.com\/aaiibb\/223122886782",
# 			"description":"회사의 <b>역사<\/b> The history of a company 학교의 <b>역사<\/b>(어느 학교인지는 언급하지 않음)... 프로젝트의 <b>예산<\/b> The budge of a project 회사나 정부의 리더들 The leaders of a company or a... ",
# 			"bloggername":"파워워프~",
# 			"bloggerlink":"blog.naver.com\/aaiibb",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"구리시 선거구 폐지 한주도 구지시(龜旨市) 선거구 신설 서울... ",
# ...

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

data = json.loads(response_body)
print(f"예산 역사에 대한 네이버 블로그 검색 총 수 : {data['total']}")
# Out:
# 예산 역사에 대한 네이버 블로그 검색 총 수 : 297689

# %%
## 예산군에 대한 정보가 아닌 "예산" (금액)에 대한 이야기가 더 많은 것 같음
df = pd.DataFrame(data['items'])
# data['items']
df[df['title'].str.contains('예산')]['link']
# Out:
# 3          https://blog.naver.com/lalalong/223122866139
# 18      https://blog.naver.com/small2great/223122762782
# 56    https://blog.naver.com/trip-of-nature/22312252...
# 68        https://blog.naver.com/koogh9510/223122469313
# Name: link, dtype: object

# %% [markdown]
# ---
# 예산군 역사로 명확하게 검색

# %%
## 예산 역사로 블로그 검색 변경 
import os
import sys
import urllib.request
client_id = "JmnMMdzgCYser7RBx1Gw"
client_secret = "nKQLDSxVE1"
encText = urllib.parse.quote("예산군 역사")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100&start=1&sort=date" # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 07 Jun 2023 22:23:59 +0900",
# 	"total":10942,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"2023년 제2회(59회) 마을만들기 대화마당",
# 			"link":"https:\/\/blog.naver.com\/cnmaeul\/223122688770",
# 			"description":"지<b>역사<\/b>회에 공헌하고자 하는 사업조직이다. 하지만 사회적 협동조합은 영리 목적보다는 취약계층 대상... &lt;2조&gt; 완료지구 조직의 활성화 방안 발표자: 이재범 팀장(<b>예산군<\/b> 행복마을지원센터) 완료지구 조직이... ",
# 			"bloggername":"충남마을만들기 지원센터",
# 			"bloggerlink":"blog.naver.com\/cnmaeul",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"[충청남도] 1박 2일 충남 알짜베기 여행 :: 서산 해미읍성, 당진... ",
# 			"link":"https:\/\/blog.naver.com\/trip-of-nature\/223122527520",
# 			"description":"해미읍성은 천주교신자들에 대한 가슴 아픈 <b>역사<\/b>를 지닌 곳으로 내포 지방의 천주교 박해 때... 아그로랜드 주소: 충남 <b>예산군<\/b> 고덕면 상몽2길 231 영업시간: 하절기: 10:00 - 18:00 \/ 동절기: 10:00 - 17:00 휴무... ",
# 			"bloggername":"여행, 예쁨의 발견",
# 			"bloggerlink":"blog.naver.com\/trip-of-nature",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"백종원 예산시장 다녀왔지요",
# ...

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

data = json.loads(response_body)
print(f"예산군 역사에 대한 네이버 블로그 검색 총 수 : {data['total']}")
# Out:
# 예산군 역사에 대한 네이버 블로그 검색 총 수 : 10942

# %%
## 예산군에 대한 정보가 아닌 "예산" (금액)에 대한 이야기가 더 많은 것 같음
df = pd.DataFrame(data['items'])
# data['items']
df[df['title'].str.contains('역사')]
# Out:
#                                                 title  \
# 29            충남혁신도시 내포신도시확장 삽교역 도청<b>역사</b> 인근 토지 매매
# 31  [<b>예산군</b> 삽교읍]충남혁신도시 내포신도시 투자용지 도청<b>역사</b>...
# 42       충남 서산 예산 가볼만한곳 서산마애삼존불상 수덕사 <b>역사</b> 여행...
# 43                                        근대<b>역사</b>
# 47              9부 우리나라에 위대한 홍익인간정신을 빛낸 분들의 <b>역사</b>
# 49                             근대 <b>역사</b>를 알자 / 이형표
# 53             현존하는 성씨중 가장 오랜<b>역사</b>를 자랑하는 진주강씨...
# 78         충남 여행 <b>예산군</b> 가볼만한곳 자연과 <b>역사</b>의 아름다움
# 95                 <b>예산군</b>, 17일 의병 <b>역사</b> 토크콘서트
# 96  <b>예산군</b>, ‘제13회 의병의 날 기념’ 의병 <b>역사</b> 토크콘서트 개최
# 97  <b>예산군</b>, ‘제13회 의병의 날 기념’ 의병 <b>역사</b> 토크콘서트 개최
# 98          <b>예산군</b>, 의병의 날 기념 의병<b>역사</b> 토크콘서트 개최
# 99           <b>예산군</b>, 최태성 강사 초청 의병 <b>역사</b> 토크콘서트
#
#                                               link  \
# 29   https://blog.naver.com/kingforte/223115558731
# 31   https://blog.naver.com/kingforte/223115478731
# ...

# %%
df.to_csv("예산군역사_블로그_검색.csv", index = False)
