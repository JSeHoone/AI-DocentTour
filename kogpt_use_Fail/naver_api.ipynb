# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
client_id = "e8AOTHr7Gvkhh_k8Ba2y"
client_secret = "hox6MqLLFw"
url = "https://openapi.naver.com/v1/datalab/search"
body = "{\"startDate\":\"2023-01-01\",\"endDate\":\"2023-06-01\",\"timeUnit\":\"week\",\"keywordGroups\":[{\"groupName\":\"예산\",\"keywords\":[\"역사\",\"시장\",\"음식\"]}] }"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2022-12-26","endDate":"2023-06-04","timeUnit":"week","results":[{"title":"예산","keywords":["역사","시장","음식"],"data":[{"period":"2022-12-26","ratio":80.64143},{"period":"2023-01-02","ratio":84.85023},{"period":"2023-01-09","ratio":89.48762},{"period":"2023-01-16","ratio":87.59992},{"period":"2023-01-23","ratio":82.5195},{"period":"2023-01-30","ratio":86.12636},{"period":"2023-02-06","ratio":89.06385},{"period":"2023-02-13","ratio":88.04777},{"period":"2023-02-20","ratio":85.69777},{"period":"2023-02-27","ratio":90.14735},{"period":"2023-03-06","ratio":93.63864},{"period":"2023-03-13","ratio":91.78946},{"period":"2023-03-20","ratio":95.93566},{"period":"2023-03-27","ratio":95.02552},{"period":"2023-04-03","ratio":100},{"period":"2023-04-10","ratio":99.39323},{"period":"2023-04-17","ratio":97.91486},{"period":"2023-04-24","ratio":94.41394},{"period":"2023-05-01","ratio":93.95165},{"period":"2023-05-08","ratio":92.27583},{"period":"2023-05-15","ratio":92.55032},{"period":"2023
# ...

# %%
import json
data = json.loads(response_body)

# %%
import pandas as pd
from pandas.io.json import json_normalize
display(pd.json_normalize(data['results'], 'data', meta_prefix=['period','ratio'], errors = 'ignore'))
# df = json_normalize(data['results'] )
display(pd.json_normalize(data['results']))
# Out:
#         period      ratio
# 0   2022-12-26   80.64143
# 1   2023-01-02   84.85023
# 2   2023-01-09   89.48762
# 3   2023-01-16   87.59992
# 4   2023-01-23   82.51950
# 5   2023-01-30   86.12636
# 6   2023-02-06   89.06385
# 7   2023-02-13   88.04777
# 8   2023-02-20   85.69777
# 9   2023-02-27   90.14735
# 10  2023-03-06   93.63864
# 11  2023-03-13   91.78946
# 12  2023-03-20   95.93566
# 13  2023-03-27   95.02552
# 14  2023-04-03  100.00000
# 15  2023-04-10   99.39323
# 16  2023-04-17   97.91486
# 17  2023-04-24   94.41394
# 18  2023-05-01   93.95165
# 19  2023-05-08   92.27583
# 20  2023-05-15   92.55032
# 21  2023-05-22   96.47019
# 22  2023-05-29   94.52951
#   title      keywords                                               data
# 0    예산  [역사, 시장, 음식]  [{'period': '2022-12-26', 'ratio': 80.64143}, ...

# %%
df = pd.json_normalize(data['results'], 'data', meta_prefix=['period','ratio'], errors = 'ignore')
df
# Out:
#         period      ratio
# 0   2022-12-26   80.64143
# 1   2023-01-02   84.85023
# 2   2023-01-09   89.48762
# 3   2023-01-16   87.59992
# 4   2023-01-23   82.51950
# 5   2023-01-30   86.12636
# 6   2023-02-06   89.06385
# 7   2023-02-13   88.04777
# 8   2023-02-20   85.69777
# 9   2023-02-27   90.14735
# 10  2023-03-06   93.63864
# 11  2023-03-13   91.78946
# 12  2023-03-20   95.93566
# 13  2023-03-27   95.02552
# 14  2023-04-03  100.00000
# 15  2023-04-10   99.39323
# 16  2023-04-17   97.91486
# 17  2023-04-24   94.41394
# 18  2023-05-01   93.95165
# 19  2023-05-08   92.27583
# 20  2023-05-15   92.55032
# 21  2023-05-22   96.47019
# 22  2023-05-29   94.52951

# %%
df.to_csv("예산_2023.csv", index = False)

# %%
df.set_index('period', inplace=True)
df.index = pd.to_datetime(df.index)

import matplotlib.pyplot as plt
import seaborn as sns

plt.plot(df)

# %% [markdown]
# ---

# %%
# 2022년 예산 
import os
import sys
import urllib.request
client_id = "e8AOTHr7Gvkhh_k8Ba2y"
client_secret = "hox6MqLLFw"
url = "https://openapi.naver.com/v1/datalab/search"
body = "{\"startDate\":\"2022-01-01\",\"endDate\":\"2022-12-31\",\"timeUnit\":\"week\",\"keywordGroups\":[{\"groupName\":\"예산\",\"keywords\":[\"역사\",\"시장\",\"음식\"]}] }"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2021-12-27","endDate":"2023-01-01","timeUnit":"week","results":[{"title":"예산","keywords":["역사","시장","음식"],"data":[{"period":"2021-12-27","ratio":51.28417},{"period":"2022-01-03","ratio":49.88298},{"period":"2022-01-10","ratio":50.51989},{"period":"2022-01-17","ratio":47.95449},{"period":"2022-01-24","ratio":50.47841},{"period":"2022-01-31","ratio":49.56601},{"period":"2022-02-07","ratio":47.94561},{"period":"2022-02-14","ratio":48.20926},{"period":"2022-02-21","ratio":48.80765},{"period":"2022-02-28","ratio":58.15978},{"period":"2022-03-07","ratio":60.14456},{"period":"2022-03-14","ratio":58.6545},{"period":"2022-03-21","ratio":58.19533},{"period":"2022-03-28","ratio":59.01887},{"period":"2022-04-04","ratio":58.75818},{"period":"2022-04-11","ratio":62.78105},{"period":"2022-04-18","ratio":58.26939},{"period":"2022-04-25","ratio":55.28334},{"period":"2022-05-02","ratio":57.01039},{"period":"2022-05-09","ratio":58.61599},{"period":"2022-05-16","ratio":60.81701},{"period":
# ...

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

data = json.loads(response_body)
df = pd.json_normalize(data['results'], 'data', meta_prefix=['period','ratio'], errors = 'ignore')
df
# Out:
#         period      ratio
# 0   2021-12-27   51.28417
# 1   2022-01-03   49.88298
# 2   2022-01-10   50.51989
# 3   2022-01-17   47.95449
# 4   2022-01-24   50.47841
# 5   2022-01-31   49.56601
# 6   2022-02-07   47.94561
# 7   2022-02-14   48.20926
# 8   2022-02-21   48.80765
# 9   2022-02-28   58.15978
# 10  2022-03-07   60.14456
# 11  2022-03-14   58.65450
# 12  2022-03-21   58.19533
# 13  2022-03-28   59.01887
# 14  2022-04-04   58.75818
# 15  2022-04-11   62.78105
# 16  2022-04-18   58.26939
# 17  2022-04-25   55.28334
# 18  2022-05-02   57.01039
# 19  2022-05-09   58.61599
# 20  2022-05-16   60.81701
# 21  2022-05-23   63.56607
# 22  2022-05-30  100.00000
# 23  2022-06-06   60.31341
# 24  2022-06-13   60.34007
# 25  2022-06-20   56.62233
# 26  2022-06-27   52.93716
# 27  2022-07-04   53.10898
# 28  2022-07-11   52.16992
# 29  2022-07-18   51.64558
# 30  2022-07-25   52.82163
# 31  2022-08-01   55.91729
# 32  2022-08-08   54.98711
# 33  2022-08-15   54.32651
# ...

# %%
df.to_csv("예산_2022.csv", index = False)

# %%
df.set_index('period', inplace=True)
df.index = pd.to_datetime(df.index)

import matplotlib.pyplot as plt
import seaborn as sns

plt.plot(df)
